# %% [markdown]
# https://docs.llamaindex.ai/en/stable/examples/llm/bedrock/

# %%
# %pip install llama-index-llms-bedrock
# Out:
# Requirement already satisfied: llama-index-llms-bedrock in /opt/conda/lib/python3.12/site-packages (0.3.8)
# Requirement already satisfied: boto3<2.0.0,>=1.34.26 in /opt/conda/lib/python3.12/site-packages (from llama-index-llms-bedrock) (1.38.37)
# Requirement already satisfied: llama-index-core<0.13.0,>=0.12.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-llms-bedrock) (0.12.42)
# Requirement already satisfied: llama-index-llms-anthropic<0.7.0,>=0.6.3 in /opt/conda/lib/python3.12/site-packages (from llama-index-llms-bedrock) (0.6.19)
# Requirement already satisfied: botocore<1.39.0,>=1.38.37 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.38.37)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.0.1)
# Requirement already satisfied: s3transfer<0.14.0,>=0.13.0 in /opt/conda/lib/python3.12/site-packages (from boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (0.13.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.9.5)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.19.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2.1.2)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2024.10.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.4.2)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.9.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2.10.6)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2.0.39)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (9.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.17.2)
# Requirement already satisfied: anthropic>=0.52.0 in /opt/conda/lib/python3.12/site-packages (from anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (0.54.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (6.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.18.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/conda/lib/python3.12/site-packages (from anthropic>=0.52.0->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from anthropic>=0.52.0->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from anthropic>=0.52.0->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (0.10.0)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from anthropic>=0.52.0->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (1.3.1)
# Requirement already satisfied: google-auth<3,>=2 in /opt/conda/lib/python3.12/site-packages (from google-auth[requests]<3,>=2; extra == "vertex"->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (2.38.0)
# Requirement already satisfied: griffe in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.7.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.1.6)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (4.3.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.37->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.12/site-packages (from botocore<1.39.0,>=1.38.37->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (2.3.0)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.14.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2024.11.6)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.4.1)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.1.1)
# Requirement already satisfied: mypy_extensions>=0.3.0 in /opt/conda/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.26.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from google-auth<3,>=2->google-auth[requests]<3,>=2; extra == "vertex"->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.12/site-packages (from google-auth<3,>=2->google-auth[requests]<3,>=2; extra == "vertex"->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.12/site-packages (from google-auth<3,>=2->google-auth[requests]<3,>=2; extra == "vertex"->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (4.9)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (24.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.39.0,>=1.38.37->boto3<2.0.0,>=1.34.26->llama-index-llms-bedrock) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp<4,>=3.8.6->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.2.1)
# Requirement already satisfied: colorama>=0.4 in /opt/conda/lib/python3.12/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13.0,>=0.12.0->llama-index-llms-bedrock) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /opt/conda/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=2->google-auth[requests]<3,>=2; extra == "vertex"->anthropic[bedrock,vertex]>=0.52.0->llama-index-llms-anthropic<0.7.0,>=0.6.3->llama-index-llms-bedrock) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install llama-index
# Out:
# Collecting llama-index
#   Downloading llama_index-0.12.42-py3-none-any.whl.metadata (12 kB)
# Collecting llama-index-agent-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_agent_openai-0.4.11-py3-none-any.whl.metadata (439 bytes)
# Collecting llama-index-cli<0.5,>=0.4.2 (from llama-index)
#   Downloading llama_index_cli-0.4.3-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: llama-index-core<0.13,>=0.12.42 in /opt/conda/lib/python3.12/site-packages (from llama-index) (0.12.42)
# Collecting llama-index-embeddings-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl.metadata (684 bytes)
# Collecting llama-index-indices-managed-llama-cloud>=0.4.0 (from llama-index)
#   Downloading llama_index_indices_managed_llama_cloud-0.7.7-py3-none-any.whl.metadata (3.3 kB)
# Collecting llama-index-llms-openai<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_llms_openai-0.4.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting llama-index-multi-modal-llms-openai<0.6,>=0.5.0 (from llama-index)
#   Downloading llama_index_multi_modal_llms_openai-0.5.1-py3-none-any.whl.metadata (440 bytes)
# Collecting llama-index-program-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_program_openai-0.3.2-py3-none-any.whl.metadata (473 bytes)
# Collecting llama-index-question-gen-openai<0.4,>=0.3.0 (from llama-index)
#   Downloading llama_index_question_gen_openai-0.3.1-py3-none-any.whl.metadata (492 bytes)
# Collecting llama-index-readers-file<0.5,>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_file-0.4.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting llama-index-readers-llama-parse>=0.4.0 (from llama-index)
#   Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: nltk>3.8.1 in /opt/conda/lib/python3.12/site-packages (from llama-index) (3.9.1)
# Collecting openai>=1.14.0 (from llama-index-agent-openai<0.5,>=0.4.0->llama-index)
#   Downloading openai-1.88.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (3.9.5)
# Requirement already satisfied: aiosqlite in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (0.19.0)
# Requirement already satisfied: banks<3,>=2.0.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (2.1.2)
# Requirement already satisfied: dataclasses-json in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.2.18)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.2.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (2024.10.0)
# Requirement already satisfied: httpx in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (0.28.1)
# Requirement already satisfied: nest-asyncio<2,>=1.5.8 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (3.4.2)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (11.1.0)
# Requirement already satisfied: pydantic>=2.8.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (2.10.6)
# Requirement already satisfied: pyyaml>=6.0.1 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (6.0.2)
# Requirement already satisfied: requests>=2.31.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (2.32.3)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.42->llama-index) (2.0.39)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (9.0.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (0.9.0)
# Requirement already satisfied: tqdm<5,>=4.66.1 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (4.12.2)
# Requirement already satisfied: typing-inspect>=0.8.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (0.9.0)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.12/site-packages (from llama-index-core<0.13,>=0.12.42->llama-index) (1.17.2)
# Collecting llama-cloud==0.1.26 (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index)
#   Downloading llama_cloud-0.1.26-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: certifi>=2024.7.4 in /opt/conda/lib/python3.12/site-packages (from llama-cloud==0.1.26->llama-index-indices-managed-llama-cloud>=0.4.0->llama-index) (2025.1.31)
# Requirement already satisfied: beautifulsoup4<5,>=4.12.3 in /opt/conda/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (4.13.3)
# Requirement already satisfied: pandas<2.3.0 in /opt/conda/lib/python3.12/site-packages (from llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.2.3)
# Collecting pypdf<6,>=5.1.0 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading pypdf-5.6.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting striprtf<0.0.27,>=0.0.26 (from llama-index-readers-file<0.5,>=0.4.0->llama-index)
#   Downloading striprtf-0.0.26-py3-none-any.whl.metadata (2.1 kB)
# Collecting llama-parse>=0.5.0 (from llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_parse-0.6.34-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (8.1.8)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.12/site-packages (from nltk>3.8.1->llama-index) (2024.11.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (6.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.12/site-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (1.18.3)
# Requirement already satisfied: griffe in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index) (1.7.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index) (3.1.6)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.12/site-packages (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index) (4.3.6)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4<5,>=4.12.3->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.5)
# Requirement already satisfied: anyio in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.42->llama-index) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.42->llama-index) (1.0.7)
# Requirement already satisfied: idna in /opt/conda/lib/python3.12/site-packages (from httpx->llama-index-core<0.13,>=0.12.42->llama-index) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/conda/lib/python3.12/site-packages (from httpcore==1.*->httpx->llama-index-core<0.13,>=0.12.42->llama-index) (0.14.0)
# Collecting llama-cloud-services>=0.6.32 (from llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index)
#   Downloading llama_cloud_services-0.6.34-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/conda/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (0.10.0)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.12/site-packages (from openai>=1.14.0->llama-index-agent-openai<0.5,>=0.4.0->llama-index) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (2025.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.42->llama-index) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /opt/conda/lib/python3.12/site-packages (from pydantic>=2.8.0->llama-index-core<0.13,>=0.12.42->llama-index) (2.27.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.42->llama-index) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests>=2.31.0->llama-index-core<0.13,>=0.12.42->llama-index) (2.3.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.12/site-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.13,>=0.12.42->llama-index) (3.1.1)
# Requirement already satisfied: mypy_extensions>=0.3.0 in /opt/conda/lib/python3.12/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.13,>=0.12.42->llama-index) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/conda/lib/python3.12/site-packages (from dataclasses-json->llama-index-core<0.13,>=0.12.42->llama-index) (3.26.1)
# Collecting platformdirs (from banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index)
#   Downloading platformdirs-4.3.8-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /opt/conda/lib/python3.12/site-packages (from llama-cloud-services>=0.6.32->llama-parse>=0.5.0->llama-index-readers-llama-parse>=0.4.0->llama-index) (1.0.1)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.12/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.13,>=0.12.42->llama-index) (24.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<2.3.0->llama-index-readers-file<0.5,>=0.4.0->llama-index) (1.17.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/conda/lib/python3.12/site-packages (from yarl<2.0,>=1.0->aiohttp<4,>=3.8.6->llama-index-core<0.13,>=0.12.42->llama-index) (0.2.1)
# Requirement already satisfied: colorama>=0.4 in /opt/conda/lib/python3.12/site-packages (from griffe->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.12/site-packages (from jinja2->banks<3,>=2.0.0->llama-index-core<0.13,>=0.12.42->llama-index) (3.0.2)
# Downloading llama_index-0.12.42-py3-none-any.whl (7.1 kB)
# Downloading llama_index_agent_openai-0.4.11-py3-none-any.whl (14 kB)
# Downloading llama_index_cli-0.4.3-py3-none-any.whl (28 kB)
# Downloading llama_index_embeddings_openai-0.3.1-py3-none-any.whl (6.2 kB)
# Downloading llama_index_indices_managed_llama_cloud-0.7.7-py3-none-any.whl (16 kB)
# Downloading llama_cloud-0.1.26-py3-none-any.whl (266 kB)
# Downloading llama_index_llms_openai-0.4.7-py3-none-any.whl (25 kB)
# Downloading llama_index_multi_modal_llms_openai-0.5.1-py3-none-any.whl (3.4 kB)
# Downloading llama_index_program_openai-0.3.2-py3-none-any.whl (6.1 kB)
# Downloading llama_index_question_gen_openai-0.3.1-py3-none-any.whl (3.7 kB)
# Downloading llama_index_readers_file-0.4.9-py3-none-any.whl (40 kB)
# Downloading llama_index_readers_llama_parse-0.4.0-py3-none-any.whl (2.5 kB)
# Downloading llama_parse-0.6.34-py3-none-any.whl (4.9 kB)
# Downloading openai-1.88.0-py3-none-any.whl (734 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 734.3/734.3 kB 48.9 MB/s eta 0:00:00
# Downloading pypdf-5.6.0-py3-none-any.whl (304 kB)
# Downloading striprtf-0.0.26-py3-none-any.whl (6.9 kB)
# Downloading llama_cloud_services-0.6.34-py3-none-any.whl (39 kB)
# Downloading platformdirs-4.3.8-py3-none-any.whl (18 kB)
# Installing collected packages: striprtf, pypdf, platformdirs, openai, llama-cloud, llama-index-readers-file, llama-index-llms-openai, llama-index-indices-managed-llama-cloud, llama-index-embeddings-openai, llama-cloud-services, llama-parse, llama-index-multi-modal-llms-openai, llama-index-cli, llama-index-agent-openai, llama-index-readers-llama-parse, llama-index-program-openai, llama-index-question-gen-openai, llama-index
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 4.3.6
#     Uninstalling platformdirs-4.3.6:
#       Successfully uninstalled platformdirs-4.3.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda 25.1.1 requires conda-libmamba-solver>=24.11.0, but you have conda-libmamba-solver 24.9.0 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# Successfully installed llama-cloud-0.1.26 llama-cloud-services-0.6.34 llama-index-0.12.42 llama-index-agent-openai-0.4.11 llama-index-cli-0.4.3 llama-index-embeddings-openai-0.3.1 llama-index-indices-managed-llama-cloud-0.7.7 llama-index-llms-openai-0.4.7 llama-index-multi-modal-llms-openai-0.5.1 llama-index-program-openai-0.3.2 llama-index-question-gen-openai-0.3.1 llama-index-readers-file-0.4.9 llama-index-readers-llama-parse-0.4.0 llama-parse-0.6.34 openai-1.88.0 platformdirs-4.3.8 pypdf-5.6.0 striprtf-0.0.26

# %%
from llama_index.llms.bedrock import Bedrock

resp = Bedrock(
    model="amazon.titan-text-express-v1", 
).complete("Star Trek is ")
# Out:
# /tmp/ipykernel_1393/2022595835.py:3: DeprecationWarning: Call to deprecated class Bedrock. (Should use `llama-index-llms-bedrock-converse` instead, the converse API is the recommended way to use Bedrock.
# See: https://docs.llamaindex.ai/en/stable/examples/llm/bedrock_converse/)
#   resp = Bedrock(

# %%
print(resp)
# Out:
# a science fiction media franchise based on the science fiction television series created by Gene Roddenberry. The first television series, Star Trek (1966–69), aired for three seasons on the original network, NBC, before moving to Paramount Pictures for the final two seasons and a subsequent film. The franchise has since expanded to include five spin-off television series, an animated series, a live-action film series, and an additional film series.
#
# The franchise's main focus is on the adventures of Captain James T. Kirk (William Shatner) and his crew aboard the starship USS Enterprise, a futuristic spacecraft designed for interstellar travel. The series explores themes of space exploration, diplomacy, and the human condition, often featuring futuristic technologies and alien civilizations.
#
# Star Trek has been praised for its innovative storytelling, its exploration of social and political issues, and its iconic characters. It has also had a significant impact on popular culture, inspiring countless works of fiction, film, and television. The franchise has a large and dedicated fan base, and has been adapted into numerous languages and formats.
#
# One of the key elements of Star Trek is its commitment to scientific accuracy. The series features a wide range of scientific concepts and technologies, and many of these have been incorporated into real-world science and technology. For example, the warp drive, which allows the Enterprise to travel faster than the speed of light, is based on a real-world theory of physics known as the Alcubierre drive.
#
# Star Trek has also been a platform for social and political commentary. The series has addressed issues such as racism, sexism, and environmentalism, and has often portrayed characters who challenge the status quo. For example, the character of Uhura, played by Nichelle Nichols, was the first African American woman to appear on television in a non-stereotypical role.
#
# The franchise has also been a source of inspiration for many scientists and engineers. The series has featured a wide range of scientific and technical concepts, and many of these have been incorporated into real-world research and development. For example, the series' use of holographic technology has inspired the development of virtual reality technology.
#
# Star Trek has also been a popular source of merchandise. The franchise has produced a wide range of toys, games, and clothing, and has been licensed for a wide range of products. The franchise's popularity has also led to the creation of numerous fan conventions and events, which attract thousands of fans from around the
